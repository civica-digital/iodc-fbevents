# %%
import langtools

# %%
len(langtools.KEYWORDS)
# Out:
# 55

# %%
langtools.KEYWORDS.keys()
# Out:
# dict_keys(['Citizen engagement', 'Humanitarian issues ', 'Gender Equality', 'Climate', 'Budget', 'comprehensive', 'Open Data', 'Hacking data', 'Culture', 'Data and Indigenous people', 'Health', 'Ecosystems', 'Food Supply', 'Journalism', 'Disaster management', 'comparable', 'Accountability', 'Clean Water', 'Environment', 'Utilities', 'Parliaments', 'Gender', 'Open cities ', 'Education', 'Improved Governance', 'Poverty', 'Peace', 'Economic Growth', 'timely', 'Anticorruption', 'default', 'Inequality', 'Consumption', 'Well-being', 'Innovation', 'Production', 'Work', 'Transport', 'usable', 'Hunger', 'Sanitation', 'Sustainable Cities', 'interoperable', 'Economic', 'Justice', 'Energy', 'Partnernships', 'Geospatial', 'Infraestructure', 'Cities', 'Strong Institutions', 'Industry', 'Inclusive', 'accesible', 'Agriculture'])

# %%
import os

# %%
API_KEY = os.environ["bing_api"]

# %%
from py_bing_search import PyBingWebSearch

# %%
def get_results_ids_fb(query):
    search_term = query + "  site:facebook.com/events"
    bing_web = PyBingWebSearch(API_KEY, search_term)
    results = bing_web.search(limit=50, format='json') 
    set_ids = set([])
    while len(results)>0:
        print(len(results))
        set_ids = extract_pages(set_ids,results)
        results = bing_web.search(limit=50, format='json') #1-50
    return(set_ids)

# %%
import re
def get_id(incoming_url):
    event_id = incoming_url.split("events/")[1]
    event_id  = event_id.split("/")[0]
    event_id = event_id.split("?")[0]
    return event_id

# %%
get_id("https://www.facebook.com/events/779362115562316")
# Out:
# '779362115562316'

# %%
def extract_pages(set_ids, input_results):
    output_ids = []
    for result in input_results:
        user_id = get_id(result.url)
        try:
            int(user_id)
            output_ids.append(user_id)
        except:
            None
    set_ids = set_ids.union(output_ids)
    return(set_ids)

# %%
a =  get_results_ids_fb('"open data"')
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 4
# 21
# 4
# 21
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 41
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %%
len(a)
# Out:
# 501

# %%
a
# Out:
# {'1007038059378749',
#  '1013357125368194',
#  '102101223486700',
#  '1021866187885383',
#  '1022287037865229',
#  '1024744614280503',
#  '1027273057348236',
#  '1029975927045013',
#  '103059353237411',
#  '1031889193515305',
#  '1034455366627338',
#  '1034997593198927',
#  '1035923833169178',
#  '1042874912390027',
#  '1043280622413929',
#  '1043289125718446',
#  '1057311507648178',
#  '1064128190288114',
#  '1072716522759918',
#  '1074857345876945',
#  '1077343332278917',
#  '1078726415487884',
#  '1080251752017555',
#  '1082975565088154',
#  '1087913751282779',
#  '1088492417832369',
#  '1092607640799947',
#  '1095235440511202',
#  '1097469013626323',
#  '1099565216754001',
#  '1100332319988632',
#  '1110037179014579',
#  '1110454335635476',
#  '1111862435493578',
#  '1115441625153189',
#  '1122894397804672',
#  '1126604717352345',
#  '1133850986634756',
#  '1147068035311054',
#  '1148017228571673',
#  '1149107748440701',
#  '1150703014960948',
#  '115870542130170',
#  '1163436730355177',
#  '1175468665820915',
#  '1183381278352734',
#  '119918665021098',
#  '124171601122749',
#  '1272195586129121',
#  '1316474748367941',
#  '1319771304703527',
#  '1341974812494633',
#  '135965939911742',
#  '137310086404069',
#  '137618376405732',
#  '677739129025793',
#  '686952154659713',
#  '691436394301422',
#  '699491196843872',
#  '700779356712189',
#  '700888899946011',
#  '701353676672568',
#  '705208336249025',
#  '706238682806673',
#  '718076941640745',
#  '718265984965615',
#  '727119133964911',
#  '728374553965627',
#  '739526126181817',
#  '740464719345006',
#  '742228495875653',
#  '742577479189877',
#  '746374622123393',
#  '749428911797865',
#  '750997641667747',
#  '751126718361715',
#  '752893218116331',
#  '757570090986854',
#  '757879524340208',
#  '759093504134846',
#  '762034990539788',
#  '764138247065245',
#  '768995263177146',
#  '775894355802214',
#  '776303482483425',
#  '781083885369096',
#  '781654551939579',
#  '784924318305172',
#  '787258761400965',
#  '798794123587489',
#  '801677773253472',
#  '805118916266534',
#  '806570022782598',
#  '816991908446833',
#  '817495248379388',
#  '817745518352424',
#  '818352104848397',
#  '818395638250720',
#  '820101411359626',
#  '822034487808984',
#  '822107504538974',
#  '824299040989469',
#  '825083187524052',
#  '825212080922320',
#  '825987390770077',
#  '827441374045783',
#  '833605433391654',
#  '836447256409813',
#  '837631616311348',
#  '838776256183673',
#  '840997322672065',
#  '846545582057406',
#  '847621355289645',
#  '848076261986115',
#  '849886655027939',
#  '854453584612339',
#  '856185401111615',
#  '856496741143780',
#  '857989267645627',
#  '858661037533391',
#  '858779470857447',
#  '859231910777650',
#  '860381327333351',
#  '860523930675113',
#  '860887374057310',
#  '865533840223711',
#  '868223766568767',
#  '871721156253321',
#  '873820766029291',
#  '881259581935139',
#  '883049111807282',
#  '887912277972905',
#  '889456071151087',
#  '892500427469221',
#  '893918747320150',
#  '896410953779545',
#  '896496660437951',
#  '899704030108986',
#  '900640679981242',
#  '901820246521815',
#  '904896499548666',
#  '907419615982007',
#  '909220095800684',
#  '910250885740659',
#  '912399182149725',
#  '912963248801765',
#  '921290991272010',
#  '923011161110018',
#  '933007653420731',
#  '936827433081437',
#  '938972066184418',
#  '941537025867424',
#  '942543819171759',
#  '946404225377967',
#  '947102295300382',
#  '950780981684701',
#  '954629051251333',
#  '957547471005024',
#  '965866626833098',
#  '965894320117442',
#  '965996116819942',
#  '969937356395544',
#  '972285982859310',
#  '975644559113423',
#  '977141505635046',
#  '980092988733521',
#  '981531968567476',
#  '982753488470772',
#  '989149244497928',
#  '990655537619433',
#  '991659314258998',
#  '992664327431729',
#  '995926770460565',
#  '997586206985252'}

# %%
import requests
import os

client_id = os.environ['client_id']
client_secret = os.environ['client_secret']


def token():
    r = requests.get('https://graph.facebook.com/oauth/access_token?grant_type=client_credentials&client_id='+client_id+'&client_secret='+client_secret)
    access_token = r.text.split('=')[1]
    return access_token


def page_info(facebook_name, token):
    #when object type = "posts", gets posts, when "comments", gets comments.
    url = 'https://graph.facebook.com/v2.5/'+facebook_name + "?metadata=1&access_token=" + token
    r = requests.get(url)
    facebook_data= r.json()
    user_type="non"
    try:
        user_type = facebook_data["metadata"]["type"]
    except:
        user_type = "non"
    return(user_type)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f2aede9f50df> in <module>()
#       2 import os
#       3
# ----> 4 client_id = os.environ['client_id']
#       5 client_secret = os.environ['client_secret']
#       6
#
# /usr/local/Cellar/python3/3.4.1_1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/os.py in __getitem__(self, key)
#     629         except KeyError:
#     630             # raise KeyError with the original key value
# --> 631             raise KeyError(key) from None
#     632         return self.decodevalue(value)
#     633
#
# KeyError: 'client_id'
