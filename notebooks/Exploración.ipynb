# %%
import langtools

# %%
len(langtools.KEYWORDS)
# Out:
# 55

# %%
langtools.KEYWORDS.keys()
# Out:
# dict_keys(['Humanitarian issues ', 'Infraestructure', 'Improved Governance', 'Accountability', 'Citizen engagement', 'Work', 'Journalism', 'usable', 'timely', 'Health', 'comprehensive', 'Disaster management', 'Clean Water', 'Transport', 'Well-being', 'Strong Institutions', 'Energy', 'Education', 'Environment', 'interoperable', 'Sanitation', 'Hacking data', 'Justice', 'Ecosystems', 'Gender Equality', 'comparable', 'Cities', 'accesible', 'Data and Indigenous people', 'Food Supply', 'Anticorruption', 'Open Data', 'Economic', 'default', 'Parliaments', 'Consumption', 'Climate', 'Utilities', 'Peace', 'Inequality', 'Production', 'Gender', 'Open cities ', 'Partnernships', 'Agriculture', 'Budget', 'Culture', 'Industry', 'Hunger', 'Economic Growth', 'Inclusive', 'Poverty', 'Sustainable Cities', 'Innovation', 'Geospatial'])

# %%
import os

# %%
API_KEY = os.environ["bing_api"]

# %%
from py_bing_search import PyBingWebSearch

# %%
def get_results_ids_fb(query):
    search_term = query + "  site:facebook.com/events"
    bing_web = PyBingWebSearch(API_KEY, search_term)
    results = bing_web.search(limit=50, format='json') 
    set_ids = set([])
    while len(results)>0:
        print(len(results))
        set_ids = extract_pages(set_ids,results)
        results = bing_web.search(limit=50, format='json') #1-50
    return(set_ids)

# %%
import re
def get_id(incoming_url):
    event_id = incoming_url.split("events/")[1]
    event_id  = event_id.split("/")[0]
    event_id = event_id.split("?")[0]
    return event_id

# %%
get_id("https://www.facebook.com/events/779362115562316")
# Out:
# '779362115562316'

# %%
    def extract_pages(set_ids, input_results):
        output_ids = []
        for result in input_results:
            user_id = get_id(result.url)
            try:
                int(user_id)
                output_ids.append(user_id)
            except:
                None
        set_ids = set_ids.union(output_ids)
        return(set_ids)

# %%
a =  get_results_ids_fb('"open data"')
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 41
# 13
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 41
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 21
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 21

# %%
len(a)
# Out:
# 489

# %%
a
# Out:
# {'1007038059378749',
#  '1013357125368194',
#  '102101223486700',
#  '1021866187885383',
#  '1022287037865229',
#  '1024744614280503',
#  '1027273057348236',
#  '1029975927045013',
#  '103059353237411',
#  '1031889193515305',
#  '1034455366627338',
#  '1034997593198927',
#  '1042874912390027',
#  '1043280622413929',
#  '1043289125718446',
#  '1057311507648178',
#  '1064128190288114',
#  '1072716522759918',
#  '1074857345876945',
#  '1077343332278917',
#  '1078726415487884',
#  '1080251752017555',
#  '1082975565088154',
#  '1087913751282779',
#  '1088492417832369',
#  '1092607640799947',
#  '1095235440511202',
#  '1097469013626323',
#  '1099565216754001',
#  '1100332319988632',
#  '1110037179014579',
#  '1110454335635476',
#  '1111862435493578',
#  '1115441625153189',
#  '1122894397804672',
#  '1126604717352345',
#  '1133850986634756',
#  '1147068035311054',
#  '1148017228571673',
#  '1149107748440701',
#  '1150703014960948',
#  '115870542130170',
#  '1163436730355177',
# ...

# %%
import requests
import os

client_id = os.environ['client_id']
client_secret = os.environ['client_secret']


def token():
    r = requests.get('https://graph.facebook.com/oauth/access_token?grant_type=client_credentials&client_id='+client_id+'&client_secret='+client_secret)
    access_token = r.text.split('=')[1]
    return access_token


def event_info(facebook_id, token):
    #when object type = "posts", gets posts, when "comments", gets comments.
    url = 'https://graph.facebook.com/v2.5/'+facebook_id + "?fields=description,end_time,place,name,start_time,id,attending_count,category,cover,is_page_owned&access_token=" + token
    r = requests.get(url)
    facebook_data= r.json()
    return(facebook_data)

# %%
def event_data(facebook_id, data_type, token):
    url  =  'https://graph.facebook.com/v2.5/'+facebook_id + "/"+data_type+ "?limit=100&access_token=" + token
    r = requests.get(url)
    incoming_data =  r.json()["data"]
    data = []
    while len(incoming_data) > 0:
        try:
            data = data + incoming_data
            url = r.json()["paging"]["next"]
            r = requests.get(url)
            incoming_data =  r.json()["data"]
        except:
            incoming_data = []
    return data

# %%
a = event_data("1077343332278917","feed", token())

# %%
a = event_data("678484755620031","attending", token())

# %%
a
# Out:
# [{'id': '10157164454720431',
#   'name': 'Darshan Yadunath',
#   'rsvp_status': 'attending'},
#  {'id': '314846672200231',
#   'name': 'Emmanuel Wandeti',
#   'rsvp_status': 'attending'},
#  {'id': '300361703646439',
#   'name': 'Prince Emmidamos',
#   'rsvp_status': 'attending'},
#  {'id': '310028539336309',
#   'name': 'Mwanahawa Athumani',
#   'rsvp_status': 'attending'},
#  {'id': '309756472695636',
#   'name': 'Juma J Makonda',
#   'rsvp_status': 'attending'},
#  {'id': '314442948889232',
#   'name': 'Africa Unique Safaris',
#   'rsvp_status': 'attending'},
#  {'id': '1660478100945813', 'name': 'Dorn Leez', 'rsvp_status': 'attending'},
#  {'id': '1593093840984740',
#   'name': 'Songoro Salum',
#   'rsvp_status': 'attending'},
#  {'id': '1632340477058115',
#   'name': 'King-m Claxic',
#   'rsvp_status': 'attending'},
#  {'id': '1640274472931285',
#   'name': 'Adam Mohamed',
#   'rsvp_status': 'attending'},
# ...

# %%
def get_event_profile(facebook_id, token):
    data = event_info(facebook_id, token())
    data["attending"] = event_data(facebook_id,"attending", token())
    data["feed"] =  event_data(facebook_id,"feed", token())
    return data

# %%
a =get_event_profile("1077343332278917",token)

# %%
# Out:
# dict_keys(['description', 'attending_count', 'name', 'end_time', 'id', 'feed', 'is_page_owned', 'start_time', 'attending', 'place', 'cover'])

# %%
import db
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-38-4907f1859da6> in <module>()
# ----> 1 import db
#
# /Users/rdalanist/DropboxAnterior/CivicaDigital/IODC/iodc-fbevents/db.py in <module>()
# ----> 1 from pymongo import MongoClient
#       2 import datetime
#       3 import os
#       4 import time
#       5
#
# /usr/local/lib/python3.4/site-packages/pymongo/__init__.py in <module>()
#      88 """Current version of PyMongo."""
#      89
# ---> 90 from pymongo.collection import ReturnDocument
#      91 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      92                             MAX_SUPPORTED_WIRE_VERSION)
#
# /usr/local/lib/python3.4/site-packages/pymongo/collection.py in <module>()
#      26                      results)
#      27 from pymongo.command_cursor import CommandCursor
# ---> 28 from pymongo.cursor import Cursor
# ...

# %%
import bing

# %%
import fb

# %%
os.environ["mongo_server"] = "192.168.99.100:32768"

# %%
import db

# %%
from pymongo import MongoClient

# %%
import bson
